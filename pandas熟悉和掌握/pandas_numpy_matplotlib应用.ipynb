# %% [markdown]
# ## pandas、numpy、matplotlib

# %% [markdown]
# ### pandas

# %% [markdown]
# ### numpy

# %% [markdown]
# ### matplotlib

# %% [markdown]
# #### 使用 pyplot 绘图

# %%
import matplotlib.pyplot as plt
import math
import random

x = range(2, 26, 2)
y = [random.uniform(15, 25) for i in range(2, 26, 2)]

# 绘图, x轴, y轴, len(x)==len(y)
plt.plot(x, y)
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager
import math
import random

# 10 - 12点每一分钟的气温
temperatures = [random.randint(20, 35) for i in range(120)]

times = range(0, 120)

# 设置图形大小
plt.figure(figsize=(20, 8), dpi=80)
# 设置字体，中文字符可显示
system_font_list = [font for font in font_manager.fontManager.ttflist]
system_font_dict = dict()
for font in font_manager.fontManager.ttflist:
    system_font_dict[font.name] = font

font = font_manager.FontProperties(fname=system_font_dict.get('FangSong').fname)

# 绘图
plt.plot(times, temperatures)

# 设置x轴 rotation:旋转
xticks_labels = [f'{m}min {s}seconds' for m in range(10, 12) for s in range(0, 60)]
plt.xticks(list(times)[::15], xticks_labels[::15], rotation=0)
plt.xlabel('时间(time)', fontproperties=font)
# 设置y轴
plt.yticks(temperatures)
plt.ylabel('温度(temperature) ℃', fontproperties=font)
# 设置标题
plt.title('10-12点 每分钟温度变化图', fontproperties=font)


# 展示图形
plt.show()

# %%
from matplotlib import font_manager

[font for font in font_manager.fontManager.ttflist]
d = dict()
for font in font_manager.fontManager.ttflist:
    d[font.name]=font.fname
    print(font.fname)
d
# Out:
# e:\developer\miniconda3\envs\data_analysis\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXNonUniBol.ttf
# e:\developer\miniconda3\envs\data_analysis\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizFourSymBol.ttf
# e:\developer\miniconda3\envs\data_analysis\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizTwoSymBol.ttf
# e:\developer\miniconda3\envs\data_analysis\lib\site-packages\matplotlib\mpl-data\fonts\ttf\cmb10.ttf
# e:\developer\miniconda3\envs\data_analysis\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizFiveSymReg.ttf
# e:\developer\miniconda3\envs\data_analysis\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSansMono.ttf
# e:\developer\miniconda3\envs\data_analysis\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXGeneralBol.ttf
# e:\developer\miniconda3\envs\data_analysis\lib\site-packages\matplotlib\mpl-data\fonts\ttf\cmmi10.ttf
# ...
